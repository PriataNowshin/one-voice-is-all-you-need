# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import librosa
import numpy as np
from numpy import asarray
from numpy import save
import os
import random

from sklearn.manifold import TSNE
from numpy import reshape
import seaborn as sns
import pandas as pd

# %%
base = '/content/drive/MyDrive/THESIS/LibriSpeech_training_data'

# %%
def extract_features(file_name):

  # try:
  print(file_name)
  audio, sample_rate = librosa.load(file_name, duration=2.97)
  mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
  mfccsscaled = np.mean(mfccs.T, axis=0)

  # except Exception as e:
  #     print("Error encountered while parsing file: ", file)
  #     return None

  return mfccsscaled

# %%
# feature extract for tsne-plot

first_iteration = True

tsne_array = np.zeros(40)
samples_speaker_id = np.zeros(1, dtype=int)
file_count = 1

for dirpath, dirnames, files in os.walk(base):

  # Giving the file_count condition to pick total number of speakers/classes
  # in the support set and query set.
  if (file_count <= 10):

    new_speaker = True

    ## Just ignoring the first iteration because, we do not need the base path's
    ## files. we need the base path's directory's(speaker's) audio files.
    if first_iteration:
      first_iteration = False
      continue


    count = 1
    while (count <= 10):

      random_file = random.choice(files)

      ## This checking is for taking the speaker_id only once for a speaker
      ## rather than picking the speaker_id for each audiofiles of the same speaker
        if new_speaker:
            speaker_id = random_file.split('-')[0]
            new_speaker = False

        tsne_array = np.vstack([tsne_array, extract_features(os.path.join(*[base, speaker_id, random_file]))])

        count += 1

    file_count += 1

## Removing the 1st row from tsne array' feature vectors because of zero value
tsne_array = np.delete(tsne_array, 0, axis=0)

# %%
# tsne-plot

tsne = TSNE(n_components=2, verbose=1, random_state=123)
z = tsne.fit_transform(tsne_array)
df = pd.DataFrame()
df["y"] = y_train
df["comp-1"] = z[:,0]
df["comp-2"] = z[:,1]

sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("hls", 10),
                data=df).set(title="dataset T-SNE projection")

# %%
first_iteration = True

anchor_mfcc_scaled_samples = np.zeros(40)
positive_mfcc_scaled_samples = np.zeros(40)
negative_mfcc_scaled_samples = np.zeros(40)
samples_speaker_id = np.zeros(1, dtype=int)

## all directories list from the basepath. Used to later find the negative
## samples for each corresponding anchor samples.
all_dir_for_neg_samples = []


##For Debug
anchor_debug = []
positive_debug = []
negative_debug = []

for dirpath, dirnames, files in os.walk(base):

  new_speaker = True

  ## Just ignoring the first iteration because, we do not need the base path's
  ## files. we need the base path's directory's(speaker's) audio files.
  if first_iteration:
    all_dir_for_neg_samples += dirnames
    first_iteration = False
    continue

  speaker_id = ''
  file_counter = 1
  total_files = len(files)

  for file in files:

    ## This checking is for taking the speaker_id only once for a speaker
    ## rather than picking the speaker_id for each audiofiles of the same speaker
    if new_speaker:
      new_speaker = False
      speaker_id = file.split('-')[0]

    ## This is for the last file. whether we ignore the last file or not.
    ## only used for odd number of audiofiles of a speaker.
    if file_counter == total_files:
      if total_files % 2 != 0:
        continue

    ## This checking is for taking the first half file of a speaker(directory)
    ## to the anchor samples and the last half file is for the positive samples.
    if file_counter <= (total_files//2):

      anchor_mfcc_scaled_samples = np.vstack([anchor_mfcc_scaled_samples, extract_features(os.path.join(*[base, speaker_id, file]))])

      ## Until we are working in the same directory or the same speaker
      ## we are just stacking the same speaker id. (This is corresponding to the
      ## anchor sample's speaker).
      samples_speaker_id = np.vstack([samples_speaker_id, speaker_id])

      ## using the speaker_id for debugging
      anchor_debug.append(speaker_id)

    else:
      positive_mfcc_scaled_samples = np.vstack([positive_mfcc_scaled_samples, extract_features(os.path.join(*[base, speaker_id, file]))])

      ## using the speaker_id for debugging
      positive_debug.append(speaker_id)

    file_counter += 1


## Removing the 1st row from anchor, positive samples' feature vectors because of zero value
anchor_mfcc_scaled_samples = np.delete(anchor_mfcc_scaled_samples, 0, axis=0)
positive_mfcc_scaled_samples = np.delete(positive_mfcc_scaled_samples, 0, axis=0)
## Removing the 1st row of sample speaker_id array because of zero value
samples_speaker_id = np.delete(samples_speaker_id, 0, axis=0)


## This loop is to get the feature vectors of the negative samples for corresponding anchor samples
rows = samples_speaker_id.shape[0] # the number of rows

for index in range(rows):
  anchor_speaker = (samples_speaker_id[index])[0]

  ## Generating a random number to pick a directory which is not equal to the
  ## anchor speaker id.
  random_directory = ''
  while (True):
    random_directory = random.choice(all_dir_for_neg_samples)
    if random_directory != anchor_speaker:
      break

  negative_debug.append(random_directory)

  ## Getting the directory location of the random_directory which was found earlier
  negative_directory = os.path.join(base, random_directory)

  ## Getting the list of files from that random_directory
  negative_directory_files = os.listdir(negative_directory)

  ## Getting a Random file from the negative_directory
  random_file = random.choice(negative_directory_files)

  negative_mfcc_scaled_samples = np.vstack([negative_mfcc_scaled_samples, extract_features(os.path.join(negative_directory, random_file))])

## Removing the 1st row from negative samples' feature vectors because of zero value
negative_mfcc_scaled_samples = np.delete(negative_mfcc_scaled_samples, 0, axis=0)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7286/7286-92930-0016.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2196/2196-170151-0025.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6574/6574-120583-0008.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5126/5126-27504-0010.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1482/1482-140067-0002.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6701/6701-71401-0017.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6694/6694-70837-0035.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5750/5750-100289-0058.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8838/8838-298545-0036.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2007/2007-132570-0003.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6426/6426-64290-0021.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6904/6904-262291-0036.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1425/1425-139290-0037.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7909/7909-106369-0002.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/3905/3905-149791-0005.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/3869/3869-699-0006.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6167/6167-282391-0007.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/9026/9026-282385-0031.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7226/7226-86964-0003.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6927/6927-86043-0029.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/3157/3157-119295-0036.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2159/2159-179154-0005.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/200/200-124139-0033.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2581/2581-155520-0039.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6081/6081-41997-0029.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/56/56-1730-0002.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2592/2592-166433-0003.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6157/6157-40556-0087.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7339/7339-86765-0001.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6075/6075-57154-0046.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8527/8527-281131-0058.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/480/480-123176-0031.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4860/4860-13185-0068.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/288/288-121741-0028.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5723/5723-43296-0021.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/3664/3664-11714-0030.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8722/8722-296473-0029.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6828/6828-64738-0020.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4535/4535-279849-0021.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8747/8747-293952-0056.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4807/4807-26852-0033.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6371/6371-63713-0021.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5400/5400-34478-0031.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6690/6690-73073-0047.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6258/6258-49755-0013.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1740/1740-141148-0013.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2787/2787-157400-0068.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4108/4108-12546-0002.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2238/2238-121413-0017.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6395/6395-84349-0029.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8193/8193-116804-0017.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/3825/3825-134148-0022.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2201/2201-151776-0015.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4014/4014-186175-0005.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4267/4267-287369-0027.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2393/2393-144496-0005.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8119/8119-115686-0045.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7264/7264-92310-0012.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1958/1958-144503-0078.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7095/7095-88483-0000.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1743/1743-142912-0002.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/114/114-129317-0044.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8635/8635-295756-0001.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6395/6395-84349-0016.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4013/4013-11734-0038.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4267/4267-287369-0002.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4807/4807-26852-0019.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6529/6529-62554-0019.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1594/1594-135914-0094.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1335/1335-160602-0034.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2843/2843-152918-0103.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8498/8498-287357-0039.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1098/1098-133695-0076.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4856/4856-12103-0037.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7909/7909-106369-0002.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4014/4014-186175-0016.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/3187/3187-168497-0023.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2319/2319-138631-0036.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/731/731-365-0047.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2532/2532-154838-0036.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7991/7991-102381-0067.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/83/83-11691-0002.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1031/1031-133220-0055.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data
0036.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/464/464-126794-0023.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/3025/3025-12971-0106.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/119/119-121722-0009.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2533/2533-149939-0075.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6272/6272-70168-0034.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/39/39-121914-0002.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5723/5723-43296-0035.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2517/2517-135227-0017.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6119/6119-48032-0043.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/922/922-132291-0024.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8609/8609-262281-0013.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7148/7148-59157-0011.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7994/7994-258959-0049.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8791/8791-291101-0102.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1175/1175-126220-0025.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/3070/3070-166420-0048.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1552/1552-140651-0014.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1012/1012-133424-0018.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4586/4586-19665-0006.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1058/1058-131113-0077.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4152/4152-12926-0037.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/70/70-121127-0049.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8770/8770-295462-0025.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8797/8797-294123-0050.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1552/1552-140651-0000.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/887/887-123289-0002.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8097/8097-108005-0003.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7665/7665-104978-0011.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4640/4640-19187-0029.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1849/1849-138063-0009.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6288/6288-63101-0029.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/957/957-130588-0002.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1634/1634-141571-0084.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5206/5206-19376-0104.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5984/5984-56837-0012.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8225/8225-274374-0018.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/3242/3242-67153-0000.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5154/5154-26558-0009.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/3914/3914-10088-0014.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6080/6080-233342-0012.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7134/7134-67200-0034.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5656/5656-44576-0002.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/159/159-121891-0008.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5400/5400-34478-0038.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2774/2774-131722-0042.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/476/476-133471-0052.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1182/1182-133396-0024.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5456/5456-24741-0022.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2397/2397-162238-0044.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5206/5206-19376-0059.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/3072/3072-155948-0031.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/669/669-129061-0075.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5322/5322-7678-0001.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4098/4098-11546-0001.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/9022/9022-282357-0020.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/711/711-187464-0058.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5339/5339-14133-0019.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/3807/3807-4923-0020.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2581/2581-155520-0014.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1553/1553-140047-0014.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/770/770-131704-0037.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1040/1040-133433-0025.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6078/6078-54007-0020.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/8396/8396-120277-0014.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7314/7314-77782-0025.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/3235/3235-11599-0012.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/4039/4039-184264-0042.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/6286/6286-69422-0036.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/90/90-121085-0017.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5789/5789-57158-0031.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1961/1961-145733-0025.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/5029/5029-30593-0031.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/1066/1066-103481-0003.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/2092/2092-145706-0006.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/458/458-126290-0012.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7938/7938-109179-0023.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/7555/7555-101283-0006.flac
# /content/drive/MyDrive/THESIS/LibriSpeech_training_data/19/19-198-0011.flac

# %%
if (len(anchor_debug) == len(positive_debug)) and (len(anchor_debug) == len(negative_debug)):

  if anchor_debug == positive_debug:
    print("All indices match between Anchor and Positive")
  else:
    print("Some indices do not match between Anchor and Positive")

  check = False
  for i in range(len(anchor_debug)):
    if anchor_debug[i] == negative_debug[i]:
      check = True
      break

  if check:
    print("Some indices match between Anchor and Negative")
  else:
    print("No index matches between Anchor and Negative")

else:
  print("Lengths are different")
# Out:
# All indices match between Anchor and Positive
# No index matches between Anchor and Negative

# %%
print(len(anchor_debug))
print(len(positive_debug))
print(len(negative_debug))
print(len(samples_speaker_id))
# Out:
# 33675
# 33675
# 33675
# 33675

# %%
anchor_mfcc_scaled_samples.shape
# Out:
# (33675, 40)

# %%
positive_mfcc_scaled_samples.shape
# Out:
# (33675, 40)

# %%
negative_mfcc_scaled_samples.shape
# Out:
# (33675, 40)

# %%
anchor_mfcc_scaled_samples[1]
# Out:
# array([-4.38506042e+02,  6.16738129e+01,  7.99811554e+00,  5.37212906e+01,
#        -1.43555508e+01,  3.20328617e+00, -2.83175659e+01,  9.20974922e+00,
#        -1.71878929e+01, -8.51651287e+00, -6.58206081e+00, -1.13818955e+00,
#        -1.31066048e+00, -8.07521820e+00,  6.86008501e+00, -1.28607101e+01,
#         3.68439984e+00, -1.02860012e+01, -1.85287678e+00, -2.58285499e+00,
#        -4.93689537e+00, -4.90523529e+00, -5.66874170e+00,  8.72467875e-01,
#        -3.43097997e+00,  5.35144329e+00, -5.33776999e-01,  7.75018883e+00,
#         4.36687469e+00,  4.61056709e+00, -3.45989168e-02,  1.67759454e+00,
#         5.63966370e+00,  1.21249962e+00,  5.08640432e+00,  1.87036729e+00,
#         4.95489359e+00, -1.48943782e+00,  3.16615015e-01, -1.61731231e+00])

# %%
positive_mfcc_scaled_samples[1]
# Out:
# array([-3.83090210e+02,  8.71394958e+01, -1.57678194e+01,  3.32040253e+01,
#        -1.73363228e+01,  1.56117928e+00, -2.28554001e+01, -1.11321473e+00,
#        -1.27033100e+01, -5.74067545e+00, -7.88111591e+00, -2.31858182e+00,
#        -7.91300964e+00, -2.50361538e+00,  5.22616196e+00, -1.94596329e+01,
#         8.49137497e+00, -1.17112617e+01, -3.01079178e+00, -1.49214077e+00,
#        -6.79152441e+00,  1.87976229e+00, -7.63947010e+00,  1.74341953e+00,
#        -3.02447987e+00, -2.67849296e-01, -9.69307065e-01,  4.60756016e+00,
#         4.19127512e+00,  9.12496758e+00,  9.07171631e+00,  8.58738518e+00,
#         1.02260103e+01,  2.70673752e+00,  5.08431196e+00,  9.94921029e-01,
#         4.47814178e+00,  2.21798539e-01,  1.32624462e-01, -1.18378773e-01])

# %%
negative_mfcc_scaled_samples[1]
# Out:
# array([-3.45811035e+02,  1.04266357e+02, -2.40751991e+01,  4.95007629e+01,
#        -5.03006172e+00,  7.27886200e+00, -5.25660801e+00, -1.44637120e+00,
#        -1.41303921e+01, -5.22911787e+00, -2.08406878e+00, -4.95688105e+00,
#        -2.24943542e+00, -4.22679567e+00,  6.50574207e+00, -8.91066849e-01,
#        -5.99530697e-01, -3.40216279e+00,  4.43440533e+00, -7.62123919e+00,
#        -5.82524109e+00,  4.69675362e-01, -4.52787828e+00, -2.80453229e+00,
#        -3.83745289e+00, -1.59681129e+00, -5.40812111e+00, -3.13694954e-01,
#        -4.87440395e+00, -1.33888113e+00, -2.55615377e+00, -1.43516016e+00,
#        -1.01084387e+00, -3.86926365e+00,  6.46865726e-01, -1.67125678e+00,
#         1.26112831e+00, -3.59205222e+00,  1.15791297e+00, -2.99591041e+00])

# %%
# Saving the anchor sample arrray to .npy format
anchor_samples_array_saved = asarray(anchor_mfcc_scaled_samples)
save('/content/drive/MyDrive/Colab Notebooks/thesis_code_main/feature_extracted_saved_arrays/anchor.npy', anchor_samples_array_saved)

# Saving the positive sample arrray to .npy format
positive_samples_array_saved = asarray(positive_mfcc_scaled_samples)
save('/content/drive/MyDrive/Colab Notebooks/thesis_code_main/feature_extracted_saved_arrays/positive.npy', positive_samples_array_saved)

# Saving the Negative sample arrray to .npy format
negative_samples_array_saved = asarray(negative_mfcc_scaled_samples)
save('/content/drive/MyDrive/Colab Notebooks/thesis_code_main/feature_extracted_saved_arrays/negative.npy', negative_samples_array_saved)

# Saving the Speaker_id arrray to .npy format
samples_speaker_id_array_saved = asarray(samples_speaker_id)
save('/content/drive/MyDrive/Colab Notebooks/thesis_code_main/feature_extracted_saved_arrays/speaker_id.npy', samples_speaker_id_array_saved)
